# %%
import pandas as pd
df=pd.read_csv("movies.csv",nrows=5)
print(df)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio  budget   revenue       unit  \
# 0          8.3  Government of West Bengal   70000  100000.0  Thousands
# 1          7.0             Marvel Studios     200     954.8   Millions
# 2          6.8             Marvel Studios     165     644.8   Millions
# 3          7.9             Marvel Studios     180     854.0   Millions
# 4          6.8             Marvel Studios     250     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df1=pd.read_csv("movies.csv",na_values={
'currency':['INR']})
print(df1)
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df1.to_csv("moviesedited.csv")
# This creates new csv file in the location where code is present
df1.to_csv("movieseditednoindex.csv",index=False,header=False)
# using false we can remove index and header from the file and save it
